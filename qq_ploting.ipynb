# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
N = 1200
p = 0.53
q = 1000

obs = np.random.binomial(N, p, size = q)/N

z = (obs-np.mean(obs))/np.std(obs)

stats.probplot(z, dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()
sns.distplot(z)
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>

# %%
obs = np.random.normal(N, p, size = q)/N

z = (obs-np.mean(obs))/np.std(obs)

stats.probplot(z, dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()
sns.distplot(z)
# Out:
# <AxesSubplot:>

# %%
obs = np.random.uniform(0, 50, 100)

# obs = (obs-np.mean(obs))/np.std(obs)

stats.probplot(obs, dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()
sns.distplot(z)
# Out:
# <AxesSubplot:>
